# %%
import pandas as pd
data = pd.read_csv('cs_students.csv')
data
# Out:
#      Student ID            Name  Gender  Age  GPA             Major  \
# 0             1      John Smith    Male   21  3.5  Computer Science
# 1             2   Alice Johnson  Female   20  3.2  Computer Science
# 2             3    Robert Davis    Male   22  3.8  Computer Science
# 3             4    Emily Wilson  Female   21  3.7  Computer Science
# 4             5   Michael Brown    Male   23  3.4  Computer Science
# ..          ...             ...     ...  ...  ...               ...
# 175         176    Elijah Davis    Male   22  3.7  Computer Science
# 176         177    Emma Johnson  Female   20  3.6  Computer Science
# 177         178     Liam Wilson    Male   21  3.4  Computer Science
# 178         179  Sophia Johnson  Female   22  3.5  Computer Science
# 179         180   Michael Brown    Male   23  3.7  Computer Science
#
#            Interested Domain                     Projects  \
# 0    Artificial Intelligence          Chatbot Development
# 1               Data Science               Data Analytics
# 2       Software Development           E-commerce Website
# 3            Web Development           Full-Stack Web App
# 4              Cybersecurity             Network Security
# ..                       ...                          ...
# 175          Web Development           Full-Stack Web App
# 176            Cybersecurity            Security Auditing
# 177         Machine Learning  Natural Language Processing
# 178      Database Management  SQL Database Administration
# 179          Cloud Computing  Cloud Solution Architecture
#
#                     Future Career   Python      SQL     Java
# 0     Machine Learning Researcher   Strong   Strong     Weak
# 1                  Data Scientist  Average   Strong     Weak
# 2               Software Engineer   Strong   Strong  Average
# 3                   Web Developer     Weak   Strong   Strong
# 4    Information Security Analyst  Average     Weak   Strong
# ..                            ...      ...      ...      ...
# 175                 Web Developer     Weak   Strong   Strong
# 176  Information Security Analyst   Strong  Average     Weak
# 177     Machine Learning Engineer   Strong  Average     Weak
# 178        Database Administrator     Weak   Strong  Average
# 179     Cloud Solutions Architect   Strong   Strong     Weak
#
# [180 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder

career_encoder = LabelEncoder()
data['Future Career'] = career_encoder.fit_transform(data['Future Career'])
career_mapping = {index: career for index, career in enumerate(career_encoder.classes_)}

domain_encoder = LabelEncoder()
data['Interested Domain'] = domain_encoder.fit_transform(data['Interested Domain'])
domain_mapping = {index: domain for index, domain in enumerate(domain_encoder.classes_)}

projects_encoder = LabelEncoder()
data['Projects'] = projects_encoder.fit_transform(data['Projects'])
projects_mapping = {index: project for index, project in enumerate(projects_encoder.classes_)}

career_mapping
domain_mapping
# Out:
# {0: 'Artificial Intelligence',
#  1: 'Bioinformatics',
#  2: 'Biomedical Computing',
#  3: 'Blockchain Technology',
#  4: 'Cloud Computing',
#  5: 'Computer Graphics',
#  6: 'Computer Vision',
#  7: 'Cybersecurity',
#  8: 'Data Mining',
#  9: 'Data Privacy',
#  10: 'Data Science',
#  11: 'Database Management',
#  12: 'Digital Forensics',
#  13: 'Distributed Systems',
#  14: 'Game Development',
#  15: 'Geographic Information Systems',
#  16: 'Human-Computer Interaction',
#  17: 'Information Retrieval',
#  18: 'IoT (Internet of Things)',
#  19: 'Machine Learning',
#  20: 'Mobile App Development',
#  21: 'Natural Language Processing',
#  22: 'Network Security',
#  23: 'Quantum Computing',
#  24: 'Software Development',
#  25: 'Software Engineering',
#  26: 'Web Development'}

# %%
projects_mapping
# Out:
# {0: '3D Animation',
#  1: '3D Modeling',
#  2: '3D Rendering',
#  3: 'AWS Deployment',
#  4: 'Android App',
#  5: 'Android App Development',
#  6: 'Android Game',
#  7: 'Big Data Analytics',
#  8: 'Chatbot Development',
#  9: 'Cloud Infrastructure Management',
#  10: 'Cloud Migration Specialist',
#  11: 'Cloud Solution Architecture',
#  12: 'Computer Forensic Analyst',
#  13: 'Computer Vision',
#  14: 'Cross-Platform App Development',
#  15: 'Data Analytics',
#  16: 'Data Mining',
#  17: 'Data Warehouse Design',
#  18: 'Deep Learning Models',
#  19: 'DevOps',
#  20: 'Distributed Systems Architect',
#  21: 'E-commerce Website',
#  22: 'Embedded Systems',
#  23: 'Enterprise Software Development',
#  24: 'Firewall Management',
#  25: 'Front-End Development',
#  26: 'Full-Stack Web App',
#  27: 'GCP Deployment',
#  28: 'GIS Mapping',
#  29: 'Game Development',
#  30: 'Genomic Data Analysis',
#  31: 'Healthcare Data Analyst',
#  32: 'Image Classification',
#  33: 'Image Recognition',
#  34: 'Machine Learning',
#  35: 'Market Analysis',
#  36: 'Medical Imaging Analysis',
#  37: 'Mobile App Development',
#  38: 'Mobile Game Development',
#  39: 'Natural Language Processing',
#  40: 'Network Security',
#  41: 'Neural Network Development',
#  42: 'Object Detection',
#  43: 'Penetration Testing',
#  44: 'Privacy Compliance Officer',
#  45: 'Protein Structure Prediction',
#  46: 'Quantum Algorithm Development',
#  47: 'Reinforcement Learning',
#  48: 'Robotics',
#  49: 'SQL Database Administration',
#  50: 'SQL Database Design',
#  51: 'SQL Query Optimization',
#  52: 'Search Engine Optimization',
#  53: 'Security Auditing',
#  54: 'Smart Contracts Developer',
#  55: 'Smart Home Automation',
#  56: 'Social Media Platform',
#  57: 'Statistical Analysis',
#  58: 'Usability Testing',
#  59: 'User Experience Researcher',
#  60: 'Virtual Reality Development',
#  61: 'Web Application Development',
#  62: 'iOS App',
#  63: 'iOS App Development',
#  64: 'iOS Game'}

# %%
career_mapping
# Out:
# {0: 'AI Researcher',
#  1: 'Bioinformatician',
#  2: 'Blockchain Engineer',
#  3: 'Cloud Solutions Architect',
#  4: 'Computer Vision Engineer',
#  5: 'Data Analyst',
#  6: 'Data Privacy Specialist',
#  7: 'Data Scientist',
#  8: 'Database Administrator',
#  9: 'DevOps Engineer',
#  10: 'Digital Forensics Specialist',
#  11: 'Distributed Systems Engineer',
#  12: 'Embedded Software Engineer',
#  13: 'Ethical Hacker',
#  14: 'Game Developer',
#  15: 'Geospatial Analyst',
#  16: 'Graphics Programmer',
#  17: 'Healthcare IT Specialist',
#  18: 'Information Security Analyst',
#  19: 'IoT Developer',
#  20: 'Machine Learning Engineer',
#  21: 'Machine Learning Researcher',
#  22: 'Mobile App Developer',
#  23: 'NLP Engineer',
#  24: 'NLP Research Scientist',
#  25: 'Quantum Computing Researcher',
#  26: 'Robotics Engineer',
#  27: 'SEO Specialist',
#  28: 'Security Analyst',
#  29: 'Software Engineer',
#  30: 'UX Designer',
#  31: 'VR Developer',
#  32: 'Web Developer'}

# %%
data
# Out:
#      Student ID            Name  Gender  Age  GPA             Major  \
# 0             1      John Smith    Male   21  3.5  Computer Science
# 1             2   Alice Johnson  Female   20  3.2  Computer Science
# 2             3    Robert Davis    Male   22  3.8  Computer Science
# 3             4    Emily Wilson  Female   21  3.7  Computer Science
# 4             5   Michael Brown    Male   23  3.4  Computer Science
# ..          ...             ...     ...  ...  ...               ...
# 175         176    Elijah Davis    Male   22  3.7  Computer Science
# 176         177    Emma Johnson  Female   20  3.6  Computer Science
# 177         178     Liam Wilson    Male   21  3.4  Computer Science
# 178         179  Sophia Johnson  Female   22  3.5  Computer Science
# 179         180   Michael Brown    Male   23  3.7  Computer Science
#
#      Interested Domain  Projects  Future Career   Python      SQL     Java
# 0                    0         8             21   Strong   Strong     Weak
# 1                   10        15              7  Average   Strong     Weak
# 2                   24        21             29   Strong   Strong  Average
# 3                   26        26             32     Weak   Strong   Strong
# 4                    7        40             18  Average     Weak   Strong
# ..                 ...       ...            ...      ...      ...      ...
# 175                 26        26             32     Weak   Strong   Strong
# 176                  7        53             18   Strong  Average     Weak
# 177                 19        39             20   Strong  Average     Weak
# 178                 11        49              8     Weak   Strong  Average
# 179                  4        11              3   Strong   Strong     Weak
#
# [180 rows x 12 columns]

# %%
data = data.drop('Student ID',axis=1)
data = data.drop('Name',axis=1)
data = data.drop('Major',axis=1)

# %%
data
# Out:
#      Gender  Age  GPA  Interested Domain  Projects  Future Career   Python  \
# 0      Male   21  3.5                  0         8             21   Strong
# 1    Female   20  3.2                 10        15              7  Average
# 2      Male   22  3.8                 24        21             29   Strong
# 3    Female   21  3.7                 26        26             32     Weak
# 4      Male   23  3.4                  7        40             18  Average
# ..      ...  ...  ...                ...       ...            ...      ...
# 175    Male   22  3.7                 26        26             32     Weak
# 176  Female   20  3.6                  7        53             18   Strong
# 177    Male   21  3.4                 19        39             20   Strong
# 178  Female   22  3.5                 11        49              8     Weak
# 179    Male   23  3.7                  4        11              3   Strong
#
#          SQL     Java
# 0     Strong     Weak
# 1     Strong     Weak
# 2     Strong  Average
# 3     Strong   Strong
# 4       Weak   Strong
# ..       ...      ...
# 175   Strong   Strong
# 176  Average     Weak
# 177  Average     Weak
# 178   Strong  Average
# 179   Strong     Weak
#
# [180 rows x 9 columns]

# %%
x = data['Gender'].apply(lambda x: 0 if x=="Female" else 1)
x
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 175    1
# 176    0
# 177    1
# 178    0
# 179    1
# Name: Gender, Length: 180, dtype: int64

# %%
data['Gender'] = data['Gender'].apply(lambda x: 0 if x=="Female" else 1)

# %%
data
# Out:
#      Gender  Age  GPA  Interested Domain  Projects  Future Career   Python  \
# 0         1   21  3.5                  0         8             21   Strong
# 1         0   20  3.2                 10        15              7  Average
# 2         1   22  3.8                 24        21             29   Strong
# 3         0   21  3.7                 26        26             32     Weak
# 4         1   23  3.4                  7        40             18  Average
# ..      ...  ...  ...                ...       ...            ...      ...
# 175       1   22  3.7                 26        26             32     Weak
# 176       0   20  3.6                  7        53             18   Strong
# 177       1   21  3.4                 19        39             20   Strong
# 178       0   22  3.5                 11        49              8     Weak
# 179       1   23  3.7                  4        11              3   Strong
#
#          SQL     Java
# 0     Strong     Weak
# 1     Strong     Weak
# 2     Strong  Average
# 3     Strong   Strong
# 4       Weak   Strong
# ..       ...      ...
# 175   Strong   Strong
# 176  Average     Weak
# 177  Average     Weak
# 178   Strong  Average
# 179   Strong     Weak
#
# [180 rows x 9 columns]

# %%
data = data.join(pd.get_dummies(data["Python"]).astype(int)).drop("Python",axis=1)

# %%
data
# Out:
#      Gender  Age  GPA  Interested Domain  Projects  Future Career      SQL  \
# 0         1   21  3.5                  0         8             21   Strong
# 1         0   20  3.2                 10        15              7   Strong
# 2         1   22  3.8                 24        21             29   Strong
# 3         0   21  3.7                 26        26             32   Strong
# 4         1   23  3.4                  7        40             18     Weak
# ..      ...  ...  ...                ...       ...            ...      ...
# 175       1   22  3.7                 26        26             32   Strong
# 176       0   20  3.6                  7        53             18  Average
# 177       1   21  3.4                 19        39             20  Average
# 178       0   22  3.5                 11        49              8   Strong
# 179       1   23  3.7                  4        11              3   Strong
#
#         Java  Average  Strong  Weak
# 0       Weak        0       1     0
# 1       Weak        1       0     0
# 2    Average        0       1     0
# 3     Strong        0       0     1
# 4     Strong        1       0     0
# ..       ...      ...     ...   ...
# 175   Strong        0       0     1
# 176     Weak        0       1     0
# 177     Weak        0       1     0
# 178  Average        0       0     1
# 179     Weak        0       1     0
#
# [180 rows x 11 columns]

# %%
data = data.join(pd.get_dummies(data['SQL'], prefix='SQL').astype(int)).drop("SQL",axis=1)
data = data.join(pd.get_dummies(data['Java'], prefix='Java').astype(int)).drop("Java",axis=1)
data
# Out:
#      Gender  Age  GPA  Interested Domain  Projects  Future Career  Average  \
# 0         1   21  3.5                  0         8             21        0
# 1         0   20  3.2                 10        15              7        1
# 2         1   22  3.8                 24        21             29        0
# 3         0   21  3.7                 26        26             32        0
# 4         1   23  3.4                  7        40             18        1
# ..      ...  ...  ...                ...       ...            ...      ...
# 175       1   22  3.7                 26        26             32        0
# 176       0   20  3.6                  7        53             18        0
# 177       1   21  3.4                 19        39             20        0
# 178       0   22  3.5                 11        49              8        0
# 179       1   23  3.7                  4        11              3        0
#
#      Strong  Weak  SQL_Average  SQL_Strong  SQL_Weak  Java_Average  \
# 0         1     0            0           1         0             0
# 1         0     0            0           1         0             0
# 2         1     0            0           1         0             1
# 3         0     1            0           1         0             0
# 4         0     0            0           0         1             0
# ..      ...   ...          ...         ...       ...           ...
# 175       0     1            0           1         0             0
# 176       1     0            1           0         0             0
# 177       1     0            1           0         0             0
# 178       0     1            0           1         0             1
# 179       1     0            0           1         0             0
#
#      Java_Strong  Java_Weak
# 0              0          1
# 1              0          1
# 2              0          0
# 3              1          0
# 4              1          0
# ..           ...        ...
# 175            1          0
# 176            0          1
# 177            0          1
# 178            0          0
# 179            0          1
#
# [180 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split

X = data.drop('Future Career',axis=1)
y = data['Future Career']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor

reg = RandomForestRegressor()

# %%
reg.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
reg.score(X_test,y_test)
# Out:
# 0.9235414211125956

# %%
data
# Out:
#      Gender  Age  GPA  Interested Domain  Projects  Future Career  Average  \
# 0         1   21  3.5                  0         8             21        0
# 1         0   20  3.2                 10        15              7        1
# 2         1   22  3.8                 24        21             29        0
# 3         0   21  3.7                 26        26             32        0
# 4         1   23  3.4                  7        40             18        1
# ..      ...  ...  ...                ...       ...            ...      ...
# 175       1   22  3.7                 26        26             32        0
# 176       0   20  3.6                  7        53             18        0
# 177       1   21  3.4                 19        39             20        0
# 178       0   22  3.5                 11        49              8        0
# 179       1   23  3.7                  4        11              3        0
#
#      Strong  Weak  SQL_Average  SQL_Strong  SQL_Weak  Java_Average  \
# 0         1     0            0           1         0             0
# 1         0     0            0           1         0             0
# 2         1     0            0           1         0             1
# 3         0     1            0           1         0             0
# 4         0     0            0           0         1             0
# ..      ...   ...          ...         ...       ...           ...
# 175       0     1            0           1         0             0
# 176       1     0            1           0         0             0
# 177       1     0            1           0         0             0
# 178       0     1            0           1         0             1
# 179       1     0            0           1         0             0
#
#      Java_Strong  Java_Weak
# 0              0          1
# 1              0          1
# 2              0          0
# 3              1          0
# 4              1          0
# ..           ...        ...
# 175            1          0
# 176            0          1
# 177            0          1
# 178            0          0
# 179            0          1
#
# [180 rows x 15 columns]

# %%
sample_data = {
    'Gender': 0,
    'Age': 21,
    'GPA': 3.7,
    'Interested Domain':26,
    'Projects': 1,
    'Average': 0,
    'Strong': 0,
    'Weak': 1,
    'SQL_Average': 0,
    'SQL_Strong': 1,
    'SQL_Weak': 0,
    'Java_Average': 0,
    'Java_Strong': 1,
    'Java_Weak': 0
}

single_sample_df = pd.DataFrame([sample_data])

prediction = reg.predict(single_sample_df)
print(prediction)
print(career_mapping)
# Out:
# [27.99]
# {0: 'AI Researcher', 1: 'Bioinformatician', 2: 'Blockchain Engineer', 3: 'Cloud Solutions Architect', 4: 'Computer Vision Engineer', 5: 'Data Analyst', 6: 'Data Privacy Specialist', 7: 'Data Scientist', 8: 'Database Administrator', 9: 'DevOps Engineer', 10: 'Digital Forensics Specialist', 11: 'Distributed Systems Engineer', 12: 'Embedded Software Engineer', 13: 'Ethical Hacker', 14: 'Game Developer', 15: 'Geospatial Analyst', 16: 'Graphics Programmer', 17: 'Healthcare IT Specialist', 18: 'Information Security Analyst', 19: 'IoT Developer', 20: 'Machine Learning Engineer', 21: 'Machine Learning Researcher', 22: 'Mobile App Developer', 23: 'NLP Engineer', 24: 'NLP Research Scientist', 25: 'Quantum Computing Researcher', 26: 'Robotics Engineer', 27: 'SEO Specialist', 28: 'Security Analyst', 29: 'Software Engineer', 30: 'UX Designer', 31: 'VR Developer', 32: 'Web Developer'}

# %%
import matplotlib.pyplot as plt
y_predict = reg.predict(X_test)
plt.scatter(y_test,y_predict)
